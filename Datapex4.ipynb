# %% [markdown]
# # Written by Datathon Team

# %%
# !git clone --depth=1 https://github.com/QingyongHu/RandLA-Net
# Out:
# Cloning into 'RandLA-Net'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 59 (delta 6), reused 45 (delta 2), pack-reused 0
# Unpacking objects: 100% (59/59), done.

# %%
# !pip install tensorflow=='1.15'
# Out:
# Collecting tensorflow==1.15
#   Downloading tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3 MB)
#      |████████████████████████████████| 412.3 MB 15 kB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 45.0 MB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.8.1)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.9 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.39.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 37.3 MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (3.3.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.19.5)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.37.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.1.0)
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (3.17.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (4.6.4)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.4.3)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=d02366d04f6af19501b943dbab56c774fe3686dfc70919427581502187da8c48
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.6.0
#     Uninstalling tensorboard-2.6.0:
#       Successfully uninstalled tensorboard-2.6.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.0
#     Uninstalling tensorflow-2.6.0:
#       Successfully uninstalled tensorflow-2.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.13.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# kapre 0.3.5 requires tensorflow>=2.0.0, but you have tensorflow 1.15.0 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
# !pip install open3d-python
# Out:
# Collecting open3d-python
#   Downloading open3d_python-0.7.0.0-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 5.2 MB/s
# Requirement already satisfied: widgetsnbextension in /usr/local/lib/python3.7/dist-packages (from open3d-python) (3.5.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.7/dist-packages (from open3d-python) (5.3.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from open3d-python) (7.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from open3d-python) (1.19.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->open3d-python) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->open3d-python) (5.1.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->open3d-python) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->open3d-python) (4.10.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->open3d-python) (1.0.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->open3d-python) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->open3d-python) (5.3.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->open3d-python) (0.8.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->open3d-python) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->open3d-python) (2.6.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->open3d-python) (4.7.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets->open3d-python) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets->open3d-python) (0.2.5)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook->open3d-python) (0.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook->open3d-python) (2.11.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook->open3d-python) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook->open3d-python) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->open3d-python) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->open3d-python) (2.8.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook->open3d-python) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook->open3d-python) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook->open3d-python) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook->open3d-python) (0.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook->open3d-python) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook->open3d-python) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook->open3d-python) (1.4.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook->open3d-python) (0.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook->open3d-python) (21.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook->open3d-python) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook->open3d-python) (2.4.7)
# Installing collected packages: open3d-python
# Successfully installed open3d-python-0.7.0.0

# %%
# !pwd
# Out:
# /content

# %%
# !pip install scikit-learn==0.22.2
# Out:
# Collecting scikit-learn==0.22.2
#   Downloading scikit_learn-0.22.2-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 4.5 MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.22.2) (1.19.5)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.5 requires tensorflow>=2.0.0, but you have tensorflow 1.15.0 which is incompatible.
# Successfully installed scikit-learn-0.22.2

# %%
cd /content/RandLA-Net
# Out:
# /content/RandLA-Net

# %%
# !sh compile_op.sh
# Out:
# running install
# running build
# running build_ext
# cythoning knn.pyx to knn.cpp
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/RandLA-Net/utils/nearest_neighbors/knn.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'nearest_neighbors' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I./ -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c knn.cpp -o build/temp.linux-x86_64-3.7/knn.o -std=c++11 -fopenmp
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from knn.cpp:634:
# /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I./ -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c knn_.cxx -o build/temp.linux-x86_64-3.7/knn_.o -std=c++11 -fopenmp
# In file included from knn_.cxx:6:0:
# KDTreeTableAdaptor.h: In instantiation of ‘KDTreeTableAdaptor<TableType, num_t, DIM, Distance, IndexType>::KDTreeTableAdaptor(size_t, size_t, const TableType*, int) [with TableType = float; num_t = float; int DIM = -1; Distance = nanoflann::metric_L2; IndexType = long unsigned int; size_t = long unsigned int]’:
# knn_.cxx:28:40:   required from here
# KDTreeTableAdaptor.h:131:19: warning: ‘KDTreeTableAdaptor<float, float>::m_data’ will be initialized after [-Wreorder]
#   const TableType* m_data;
#                    ^~~~~~
# KDTreeTableAdaptor.h:129:9: warning:   ‘size_t KDTreeTableAdaptor<float, float>::dim’ [-Wreorder]
#   size_t dim;
#          ^~~
# KDTreeTableAdaptor.h:134:2: warning:   when initialized here [-Wreorder]
#   KDTreeTableAdaptor(const size_t npts, const size_t dim, const TableType* mat, const int leaf_max_size = 10) : m_data(mat), dim(dim), npts(npts)
#   ^~~~~~~~~~~~~~~~~~
# creating build/lib.linux-x86_64-3.7
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/knn.o build/temp.linux-x86_64-3.7/knn_.o -o build/lib.linux-x86_64-3.7/nearest_neighbors.cpython-37m-x86_64-linux-gnu.so -std=c++11 -fopenmp
# running install_lib
# creating lib
# creating lib/python
# copying build/lib.linux-x86_64-3.7/nearest_neighbors.cpython-37m-x86_64-linux-gnu.so -> ./lib/python
# running install_egg_info
# Writing ./lib/python/KNN_NanoFLANN-0.0.0.egg-info
# running build_ext
# building 'grid_subsampling' extension
# Warning: Can't read registry to find the necessary compiler setting
# Make sure that Python modules winreg, win32api or win32con are installed.
# C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/cpp_wrappers
# creating build/temp.linux-x86_64-3.7/cpp_wrappers/cpp_utils
# creating build/temp.linux-x86_64-3.7/cpp_wrappers/cpp_utils/cloud
# creating build/temp.linux-x86_64-3.7/grid_subsampling
# compile options: '-I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c'
# extra options: '-std=c++11 -D_GLIBCXX_USE_CXX11_ABI=0'
# x86_64-linux-gnu-gcc: ../cpp_utils/cloud/cloud.cpp
# x86_64-linux-gnu-gcc: grid_subsampling/grid_subsampling.cpp
# grid_subsampling/grid_subsampling.cpp: In function ‘void grid_subsampling(std::vector<PointXYZ>&, std::vector<PointXYZ>&, std::vector<float>&, std::vector<float>&, std::vector<int>&, std::vector<int>&, float, int)’:
# grid_subsampling/grid_subsampling.cpp:99:25: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#        for (int i = 0; i < ldim; i++)
#                        ~~^~~~~~
# x86_64-linux-gnu-gcc: wrapper.cpp
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from wrapper.cpp:2:
# /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# wrapper.cpp: In function ‘PyObject* grid_subsampling_compute(PyObject*, PyObject*, PyObject*)’:
# wrapper.cpp:70:98: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#   static char *kwlist[] = {"points", "features", "classes", "sampleDl", "method", "verbose", NULL };
#                                                                                                   ^
# wrapper.cpp:70:98: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
# wrapper.cpp:70:98: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
# wrapper.cpp:70:98: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
# wrapper.cpp:70:98: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
# wrapper.cpp:70:98: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-LSlbJj/python3.7-3.7.11=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/cpp_wrappers/cpp_utils/cloud/cloud.o build/temp.linux-x86_64-3.7/grid_subsampling/grid_subsampling.o build/temp.linux-x86_64-3.7/wrapper.o -o /content/RandLA-Net/utils/cpp_wrappers/cpp_subsampling/grid_subsampling.cpython-37m-x86_64-linux-gnu.so

# %%
# !unzip /content/drive/MyDrive/StanfordLarge-ScaleIndoorSpaces3DDataset/Stanford3dDataset_v1.2_Aligned_Version.zip -d /content/RandLA-Net/data/S3DIS
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/WC_1/WC_1.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/stairs_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/hallway_9.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/bookcase_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/ceiling_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/column_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/Annotations/wall_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_2/office_2.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_5/storage_5.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_18.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_16.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/bookcase_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_19.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/bookcase_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_16.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/bookcase_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/bookcase_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/ceiling_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/column_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_17.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/door_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/Annotations/wall_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_8/hallway_8.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/table_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/ceiling_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/Annotations/wall_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_1/office_1.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/Annotations/wall_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_9/storage_9.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/board_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_2/storage_2.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_16.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/door_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/sofa_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_18.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_20.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/door_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_22.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/door_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/board_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/floor_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_17.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/stairs_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_19.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/clutter_21.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/Annotations/door_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_2/hallway_2.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/hallway_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_16.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/door_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/sofa_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/sofa_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/door_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/ceiling_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_18.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_20.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/door_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_22.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/door_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/floor_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/table_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/floor_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/floor_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_17.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_23.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/bookcase_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/stairs_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_19.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/ceiling_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/ceiling_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/clutter_21.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/door_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_10/Annotations/wall_5.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/table_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/table_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/ceiling_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/Annotations/wall_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/office_12/office_12.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/stairs_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_4/hallway_4.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/storage_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/.DS_Store
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/storage_1/Annotations/clutter_3.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_11/
# ...
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/chair_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_18.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_20.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_22.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/board_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/bookcase_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_17.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_19.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/chair_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/window_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/column_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/Annotations/clutter_21.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_18/office_18.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_16.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/sofa_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/sofa_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/beam_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/table_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/table_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_17.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/window_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/Annotations/column_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_8/office_8.txt
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/.DS_Store
#    creating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_16.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_7.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_11.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/floor_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/wall_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/bookcase_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_18.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_20.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/ceiling_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_9.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_22.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_10.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/wall_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_12.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/wall_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/board_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/chair_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/bookcase_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_15.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/chair_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/bookcase_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_14.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/bookcase_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_13.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_17.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/wall_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_6.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_5.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_23.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_2.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/bookcase_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/bookcase_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/beam_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_4.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/door_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_19.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_3.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/table_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/window_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_8.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/column_1.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/Annotations/clutter_21.txt
#   inflating: /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/office_22/office_22.txt

# %%
# !unzip /content/drive/MyDrive/scene_3.zip -d /content/RandLA-Net/data/S3DIS/Datathon/Area_3/scene_3
# Out:
# Archive:  /content/drive/MyDrive/scene_3.zip
#   inflating: /content/RandLA-Net/data/S3DIS/Datathon/Area_3/scene_3/scene_3.txt

# %%
# !mv /content/RandLA-Net/data/S3DIS/Datathon/Area_3/*.txt /content/RandLA-Net/data/S3DIS/Datathon/Area_3/scene_3/Annotations

# %%
cp -r /content/RandLA-Net/data/S3DIS/Datathon/Area_2/scene_2 /content/RandLA-Net/data/S3DIS/Datathon/Area_6

# %%
# !rm -r /content/RandLA-Net/data/S3DIS/Datathon/Area_1

# %% [markdown]
# !rm -r /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# import utils.nearest_neighbors.lib.python.nearest_neighbors as nearest_neighbors

# %%
import open3d
from os.path import join
import numpy as np
import colorsys, random, os, sys
import pandas as pd

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

BASE_DIR = os.path.dirname(os.path.abspath(__file__))

sys.path.append(BASE_DIR)
sys.path.append(os.path.join(BASE_DIR, 'utils'))

import cpp_wrappers.cpp_subsampling.grid_subsampling as cpp_subsampling
import utils.nearest_neighbors.lib.python.nearest_neighbors as nearest_neighbors


class ConfigSemanticKITTI:
    k_n = 16  # KNN
    num_layers = 4  # Number of layers
    num_points = 4096 * 11  # Number of input points
    num_classes = 19  # Number of valid classes
    sub_grid_size = 0.06  # preprocess_parameter

    batch_size = 6  # batch_size during training
    val_batch_size = 20  # batch_size during validation and test
    train_steps = 500  # Number of steps per epochs
    val_steps = 100  # Number of validation steps per epoch

    sub_sampling_ratio = [4, 4, 4, 4]  # sampling ratio of random sampling at each layer
    d_out = [16, 64, 128, 256]  # feature dimension
    num_sub_points = [num_points // 4, num_points // 16, num_points // 64, num_points // 256]

    noise_init = 3.5  # noise initial parameter
    max_epoch = 100  # maximum epoch during training
    learning_rate = 1e-2  # initial learning rate
    lr_decays = {i: 0.95 for i in range(0, 500)}  # decay rate of learning rate

    train_sum_dir = 'train_log'
    saving = True
    saving_path = None


class ConfigS3DIS:
    k_n = 16  # KNN
    num_layers = 5  # Number of layers
    num_points = 40960  # Number of input points
    num_classes = 13  # Number of valid classes
    sub_grid_size = 0.04  # preprocess_parameter

    batch_size = 6  # batch_size during training
    val_batch_size = 20  # batch_size during validation and test
    train_steps = 500  # Number of steps per epochs
    val_steps = 100  # Number of validation steps per epoch

    sub_sampling_ratio = [4, 4, 4, 4, 2]  # sampling ratio of random sampling at each layer
    d_out = [16, 64, 128, 256, 512]  # feature dimension

    noise_init = 3.5  # noise initial parameter
    max_epoch = 100  # maximum epoch during training
    learning_rate = 1e-2  # initial learning rate
    lr_decays = {i: 0.95 for i in range(0, 500)}  # decay rate of learning rate

    train_sum_dir = 'train_log'
    saving = True
    saving_path = None


class ConfigSemantic3D:
    k_n = 16  # KNN
    num_layers = 5  # Number of layers
    num_points = 65536  # Number of input points
    num_classes = 8  # Number of valid classes
    sub_grid_size = 0.06  # preprocess_parameter

    batch_size = 4  # batch_size during training
    val_batch_size = 16  # batch_size during validation and test
    train_steps = 500  # Number of steps per epochs
    val_steps = 100  # Number of validation steps per epoch

    sub_sampling_ratio = [4, 4, 4, 4, 2]  # sampling ratio of random sampling at each layer
    d_out = [16, 64, 128, 256, 512]  # feature dimension

    noise_init = 3.5  # noise initial parameter
    max_epoch = 100  # maximum epoch during training
    learning_rate = 1e-2  # initial learning rate
    lr_decays = {i: 0.95 for i in range(0, 500)}  # decay rate of learning rate

    train_sum_dir = 'train_log'
    saving = True
    saving_path = None

    augment_scale_anisotropic = True
    augment_symmetries = [True, False, False]
    augment_rotation = 'vertical'
    augment_scale_min = 0.8
    augment_scale_max = 1.2
    augment_noise = 0.001
    augment_occlusion = 'none'
    augment_color = 0.8


class DataProcessing:
    @staticmethod
    def load_pc_semantic3d(filename):
        pc_pd = pd.read_csv(filename, header=None, delim_whitespace=True, dtype=np.float16)
        pc = pc_pd.values
        return pc

    @staticmethod
    def load_label_semantic3d(filename):
        label_pd = pd.read_csv(filename, header=None, delim_whitespace=True, dtype=np.uint8)
        cloud_labels = label_pd.values
        return cloud_labels

    @staticmethod
    def load_pc_kitti(pc_path):
        scan = np.fromfile(pc_path, dtype=np.float32)
        scan = scan.reshape((-1, 4))
        points = scan[:, 0:3]  # get xyz
        return points

    @staticmethod
    def load_label_kitti(label_path, remap_lut):
        label = np.fromfile(label_path, dtype=np.uint32)
        label = label.reshape((-1))
        sem_label = label & 0xFFFF  # semantic label in lower half
        inst_label = label >> 16  # instance id in upper half
        assert ((sem_label + (inst_label << 16) == label).all())
        sem_label = remap_lut[sem_label]
        return sem_label.astype(np.int32)

    @staticmethod
    def get_file_list(dataset_path, test_scan_num):
        seq_list = np.sort(os.listdir(dataset_path))

        train_file_list = []
        test_file_list = []
        val_file_list = []
        for seq_id in seq_list:
            seq_path = join(dataset_path, seq_id)
            pc_path = join(seq_path, 'velodyne')
            if seq_id == '08':
                val_file_list.append([join(pc_path, f) for f in np.sort(os.listdir(pc_path))])
                if seq_id == test_scan_num:
                    test_file_list.append([join(pc_path, f) for f in np.sort(os.listdir(pc_path))])
            elif int(seq_id) >= 11 and seq_id == test_scan_num:
                test_file_list.append([join(pc_path, f) for f in np.sort(os.listdir(pc_path))])
            elif seq_id in ['00', '01', '02', '03', '04', '05', '06', '07', '09', '10']:
                train_file_list.append([join(pc_path, f) for f in np.sort(os.listdir(pc_path))])

        train_file_list = np.concatenate(train_file_list, axis=0)
        val_file_list = np.concatenate(val_file_list, axis=0)
        test_file_list = np.concatenate(test_file_list, axis=0)
        return train_file_list, val_file_list, test_file_list

    @staticmethod
    def knn_search(support_pts, query_pts, k):
        """
        :param support_pts: points you have, B*N1*3
        :param query_pts: points you want to know the neighbour index, B*N2*3
        :param k: Number of neighbours in knn search
        :return: neighbor_idx: neighboring points indexes, B*N2*k
        """

        neighbor_idx = nearest_neighbors.knn_batch(support_pts, query_pts, k, omp=True)
        return neighbor_idx.astype(np.int32)

    @staticmethod
    def data_aug(xyz, color, labels, idx, num_out):
        num_in = len(xyz)
        dup = np.random.choice(num_in, num_out - num_in)
        xyz_dup = xyz[dup, ...]
        xyz_aug = np.concatenate([xyz, xyz_dup], 0)
        color_dup = color[dup, ...]
        color_aug = np.concatenate([color, color_dup], 0)
        idx_dup = list(range(num_in)) + list(dup)
        idx_aug = idx[idx_dup]
        label_aug = labels[idx_dup]
        return xyz_aug, color_aug, idx_aug, label_aug

    @staticmethod
    def shuffle_idx(x):
        # random shuffle the index
        idx = np.arange(len(x))
        np.random.shuffle(idx)
        return x[idx]

    @staticmethod
    def shuffle_list(data_list):
        indices = np.arange(np.shape(data_list)[0])
        np.random.shuffle(indices)
        data_list = data_list[indices]
        return data_list

    @staticmethod
    def grid_sub_sampling(points, features=None, labels=None, grid_size=0.1, verbose=0):
        """
        CPP wrapper for a grid sub_sampling (method = barycenter for points and features
        :param points: (N, 3) matrix of input points
        :param features: optional (N, d) matrix of features (floating number)
        :param labels: optional (N,) matrix of integer labels
        :param grid_size: parameter defining the size of grid voxels
        :param verbose: 1 to display
        :return: sub_sampled points, with features and/or labels depending of the input
        """

        if (features is None) and (labels is None):
            return cpp_subsampling.compute(points, sampleDl=grid_size, verbose=verbose)
        elif labels is None:
            return cpp_subsampling.compute(points, features=features, sampleDl=grid_size, verbose=verbose)
        elif features is None:
            return cpp_subsampling.compute(points, classes=labels, sampleDl=grid_size, verbose=verbose)
        else:
            return cpp_subsampling.compute(points, features=features, classes=labels, sampleDl=grid_size,
                                           verbose=verbose)

    @staticmethod
    def IoU_from_confusions(confusions):
        """
        Computes IoU from confusion matrices.
        :param confusions: ([..., n_c, n_c] np.int32). Can be any dimension, the confusion matrices should be described by
        the last axes. n_c = number of classes
        :return: ([..., n_c] np.float32) IoU score
        """

        # Compute TP, FP, FN. This assume that the second to last axis counts the truths (like the first axis of a
        # confusion matrix), and that the last axis counts the predictions (like the second axis of a confusion matrix)
        TP = np.diagonal(confusions, axis1=-2, axis2=-1)
        TP_plus_FN = np.sum(confusions, axis=-1)
        TP_plus_FP = np.sum(confusions, axis=-2)

        # Compute IoU
        IoU = TP / (TP_plus_FP + TP_plus_FN - TP + 1e-6)

        # Compute mIoU with only the actual classes
        mask = TP_plus_FN < 1e-3
        counts = np.sum(1 - mask, axis=-1, keepdims=True)
        mIoU = np.sum(IoU, axis=-1, keepdims=True) / (counts + 1e-6)

        # If class is absent, place mIoU in place of 0 IoU to get the actual mean later
        IoU += mask * mIoU
        return IoU

    @staticmethod
    def get_class_weights(dataset_name):
        # pre-calculate the number of points in each category
        num_per_class = []
        if dataset_name is 'S3DIS':
            num_per_class = np.array([3370714, 2856755, 4919229, 318158, 375640, 478001, 974733,
                                      650464, 791496, 88727, 1284130, 229758, 2272837], dtype=np.int32)
        elif dataset_name is 'Semantic3D':
            num_per_class = np.array([5181602, 5012952, 6830086, 1311528, 10476365, 946982, 334860, 269353],
                                     dtype=np.int32)
        elif dataset_name is 'SemanticKITTI':
            num_per_class = np.array([55437630, 320797, 541736, 2578735, 3274484, 552662, 184064, 78858,
                                      240942562, 17294618, 170599734, 6369672, 230413074, 101130274, 476491114,
                                      9833174, 129609852, 4506626, 1168181])
        weight = num_per_class / float(sum(num_per_class))
        ce_label_weight = 1 / (weight + 0.02)
        return np.expand_dims(ce_label_weight, axis=0)


class Plot:
    @staticmethod
    def random_colors(N, bright=True, seed=0):
        brightness = 1.0 if bright else 0.7
        hsv = [(0.15 + i / float(N), 1, brightness) for i in range(N)]
        colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
        random.seed(seed)
        random.shuffle(colors)
        return colors

    @staticmethod
    def draw_pc(pc_xyzrgb):
        pc = open3d.PointCloud()
        pc.points = open3d.Vector3dVector(pc_xyzrgb[:, 0:3])
        if pc_xyzrgb.shape[1] == 3:
            open3d.draw_geometries([pc])
            return 0
        if np.max(pc_xyzrgb[:, 3:6]) > 20:  ## 0-255
            pc.colors = open3d.Vector3dVector(pc_xyzrgb[:, 3:6] / 255.)
        else:
            pc.colors = open3d.Vector3dVector(pc_xyzrgb[:, 3:6])
        open3d.draw_geometries([pc])
        return 0

    @staticmethod
    def draw_pc_sem_ins(pc_xyz, pc_sem_ins, plot_colors=None):
        """
        pc_xyz: 3D coordinates of point clouds
        pc_sem_ins: semantic or instance labels
        plot_colors: custom color list
        """
        if plot_colors is not None:
            ins_colors = plot_colors
        else:
            ins_colors = Plot.random_colors(len(np.unique(pc_sem_ins)) + 1, seed=2)

        ##############################
        sem_ins_labels = np.unique(pc_sem_ins)
        sem_ins_bbox = []
        Y_colors = np.zeros((pc_sem_ins.shape[0], 3))
        for id, semins in enumerate(sem_ins_labels):
            valid_ind = np.argwhere(pc_sem_ins == semins)[:, 0]
            if semins <= -1:
                tp = [0, 0, 0]
            else:
                if plot_colors is not None:
                    tp = ins_colors[semins]
                else:
                    tp = ins_colors[id]

            Y_colors[valid_ind] = tp

            ### bbox
            valid_xyz = pc_xyz[valid_ind]

            xmin = np.min(valid_xyz[:, 0]);
            xmax = np.max(valid_xyz[:, 0])
            ymin = np.min(valid_xyz[:, 1]);
            ymax = np.max(valid_xyz[:, 1])
            zmin = np.min(valid_xyz[:, 2]);
            zmax = np.max(valid_xyz[:, 2])
            sem_ins_bbox.append(
                [[xmin, ymin, zmin], [xmax, ymax, zmax], [min(tp[0], 1.), min(tp[1], 1.), min(tp[2], 1.)]])

        Y_semins = np.concatenate([pc_xyz[:, 0:3], Y_colors], axis=-1)
        Plot.draw_pc(Y_semins)
        return Y_semins

# %% [markdown]
# /content/RandLA-Net/utils/meta/anno_paths.txt
#
# Area_1/scene_1/Annotations
# Area_2/scene_1/Annotations
# Area_3/scene_1/Annotations
# Area_4/scene_1/Annotations
# Area_5/scene_1/Annotations
# Area_6/scene_1/Annotations

# %% [markdown]
# /content/RandLA-Net/utils/data_prepare_s3dis.py
#
# dataset_path = '/content/RandLA-Net/data/S3DIS/Datathon'

# %% [markdown]
# /content/RandLA-Net/utils/meta/class_names.txt
#
# roof
# wall
# window
# door

# %%
# !python utils/data_prepare_s3dis.py
# Out:
# /content/RandLA-Net/data/S3DIS/Datathon/Area_1/scene_1/Annotations
# /content/RandLA-Net/data/S3DIS/Datathon/Area_2/scene_2/Annotations
# /content/RandLA-Net/data/S3DIS/Datathon/Area_3/scene_3/Annotations
# /content/RandLA-Net/data/S3DIS/Datathon/Area_4/scene_4/Annotations
# /content/RandLA-Net/data/S3DIS/Datathon/Area_5/scene_5/Annotations
# /content/RandLA-Net/data/S3DIS/Datathon/Area_6/scene_6/Annotations

# %%
cp -r /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/scene_2  /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_1/scence_1

# %%
# !python main_S3DIS.py --mode train --gpu 0
# Out:
# Area_2_scene_2_KDTree.pkl 38.5 MB loaded in 0.1s
# Area_5_scene_5_KDTree.pkl 21.1 MB loaded in 0.0s
# Area_6_scene_6_KDTree.pkl 38.5 MB loaded in 0.1s
# Area_4_scene_4_KDTree.pkl 19.0 MB loaded in 0.0s
# Area_1_scene_1_KDTree.pkl 21.1 MB loaded in 0.0s
# Area_3_scene_3_KDTree.pkl 119.8 MB loaded in 0.3s
#
# Preparing reprojected indices for testing
# Area_5_scene_5 done in 0.0s
# Initiating input pipelines
# WARNING:tensorflow:From main_S3DIS.py:170: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From main_S3DIS.py:205: The name tf.data.Iterator is deprecated. Please use tf.compat.v1.data.Iterator instead.
#
# WARNING:tensorflow:From main_S3DIS.py:205: DatasetV1.output_types (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_types(dataset)`.
# WARNING:tensorflow:From main_S3DIS.py:205: DatasetV1.output_shapes (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:347: Iterator.output_types (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_types(iterator)`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:348: Iterator.output_shapes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(iterator)`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:350: Iterator.output_classes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_classes(iterator)`.
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:29: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:42: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:107: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:108: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:49: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:54: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:22: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/util/dispatch.py:180: batch_gather (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.batch_gather` is deprecated, please use `tf.gather` with `batch_dims=-1` instead.
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:572: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:67: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:265: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:82: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:83: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:83: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:90: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:95: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:96: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:98: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:99: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:100: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:101: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# ****EPOCH 0****
# Step 00000050 L_out=11.683 Acc=0.19 --- 1634.34 ms/batch
# Step 00000100 L_out=10.382 Acc=0.29 --- 1620.91 ms/batch
# Step 00000150 L_out=11.000 Acc=0.31 --- 1613.92 ms/batch
# Step 00000200 L_out=11.546 Acc=0.40 --- 1601.60 ms/batch
# Step 00000250 L_out=11.206 Acc=0.41 --- 1564.77 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.2856513916015625
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  0.00   nan   nan 28.13  0.00   nan   nan   nan   nan   nan  1.62
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 1****
# Step 00000300 L_out=9.996 Acc=0.20 --- 1601.20 ms/batch
# Step 00000350 L_out=20.497 Acc=0.21 --- 1568.87 ms/batch
# Step 00000400 L_out=10.199 Acc=0.25 --- 1593.66 ms/batch
# Step 00000450 L_out=10.520 Acc=0.39 --- 1616.36 ms/batch
# Step 00000500 L_out=10.524 Acc=0.28 --- 1545.24 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.2957740966796875
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  0.00   nan   nan 28.44  0.00   nan   nan   nan   nan   nan  3.59
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 2****
# Step 00000550 L_out=13.358 Acc=0.23 --- 1605.39 ms/batch
# Step 00000600 L_out=12.243 Acc=0.45 --- 1617.80 ms/batch
# Step 00000650 L_out=9.908 Acc=0.41 --- 1630.72 ms/batch
# Step 00000700 L_out=10.189 Acc=0.35 --- 1602.15 ms/batch
# Step 00000750 L_out=11.645 Acc=0.35 --- 1591.60 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.2822927978515625
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  0.00   nan   nan 27.92  0.00   nan   nan   nan   nan   nan  0.82
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 3****
# Step 00000800 L_out=10.515 Acc=0.27 --- 1603.82 ms/batch
# Step 00000850 L_out=9.894 Acc=0.28 --- 1607.42 ms/batch
# Step 00000900 L_out=10.804 Acc=0.30 --- 1615.32 ms/batch
# Step 00000950 L_out=10.466 Acc=0.50 --- 1607.29 ms/batch
# Step 00001000 L_out=10.872 Acc=0.21 --- 1579.87 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.30723402099609376
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  0.00   nan   nan 28.09  0.00   nan   nan   nan   nan   nan  7.63
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 4****
# Step 00001050 L_out=9.998 Acc=0.34 --- 1565.18 ms/batch
# Step 00001100 L_out=10.753 Acc=0.47 --- 1589.46 ms/batch
# Step 00001150 L_out=14.581 Acc=0.52 --- 1587.96 ms/batch
# Step 00001200 L_out=14.432 Acc=0.31 --- 1572.55 ms/batch
# Step 00001250 L_out=10.096 Acc=0.26 --- 1558.41 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.42763160400390626
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  0.00   nan   nan 31.86  0.00   nan   nan   nan   nan   nan 29.85
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 5****
# Step 00001300 L_out=9.896 Acc=0.51 --- 1593.74 ms/batch
# Step 00001350 L_out=9.477 Acc=0.42 --- 1570.64 ms/batch
# Step 00001400 L_out=12.542 Acc=0.53 --- 1583.38 ms/batch
# Step 00001450 L_out=13.426 Acc=0.27 --- 1612.13 ms/batch
# Step 00001500 L_out=9.488 Acc=0.37 --- 1548.92 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.49000166015625
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan 12.77   nan   nan 31.77  0.00   nan   nan   nan   nan   nan 39.57
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 6****
# Step 00001550 L_out=8.870 Acc=0.43 --- 1624.18 ms/batch
# Step 00001600 L_out=7.804 Acc=0.45 --- 1610.05 ms/batch
# Step 00001650 L_out=10.299 Acc=0.45 --- 1582.37 ms/batch
# Step 00001700 L_out=8.913 Acc=0.39 --- 1575.13 ms/batch
# Step 00001750 L_out=7.664 Acc=0.43 --- 1556.97 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.46053135986328125
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  3.09   nan   nan 33.78  0.00   nan   nan   nan   nan   nan 33.85
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 7****
# Step 00001800 L_out=9.004 Acc=0.35 --- 1612.72 ms/batch
# Step 00001850 L_out=12.326 Acc=0.42 --- 1628.89 ms/batch
# Step 00001900 L_out=13.593 Acc=0.40 --- 1591.23 ms/batch
# Step 00001950 L_out=8.120 Acc=0.45 --- 1590.68 ms/batch
# Step 00002000 L_out=8.950 Acc=0.32 --- 1560.71 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.45602276611328124
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan  9.63   nan   nan 32.85  0.00   nan   nan   nan   nan   nan 32.34
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 8****
# Step 00002050 L_out=7.601 Acc=0.26 --- 1609.29 ms/batch
# Step 00002100 L_out=6.757 Acc=0.53 --- 1621.91 ms/batch
# Step 00002150 L_out=8.411 Acc=0.44 --- 1611.90 ms/batch
# Step 00002200 L_out=9.300 Acc=0.56 --- 1646.95 ms/batch
# Step 00002250 L_out=6.426 Acc=0.48 --- 1566.74 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.4562797973632812
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan 12.77   nan   nan 34.46  0.00   nan   nan   nan   nan   nan 30.61
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 9****
# Step 00002300 L_out=11.028 Acc=0.57 --- 1569.63 ms/batch
# Step 00002350 L_out=8.397 Acc=0.40 --- 1610.41 ms/batch
# Step 00002400 L_out=10.150 Acc=0.36 --- 1600.80 ms/batch
# Step 00002450 L_out=8.790 Acc=0.45 --- 1614.31 ms/batch
# Step 00002500 L_out=9.176 Acc=0.50 --- 1565.77 ms/batch
# 0 / 100
# 50 / 100
# /content/RandLA-Net/RandLANet.py:243: RuntimeWarning: invalid value encountered in true_divide
#   iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# eval accuracy: 0.46013638916015626
# mean IOU:nan
# Mean IoU = nan%
# --------------------------------------------------------------------------------------
#   nan |   nan   nan 16.23   nan   nan 36.18  2.67   nan   nan   nan   nan   nan 30.65
# --------------------------------------------------------------------------------------
#
# Best m_IoU is: 0.000
# ****EPOCH 10****
# finished

# %%
# !python main_S3DIS.py --mode test --gpu 0
# Out:
# Area_2_scene_2_KDTree.pkl 38.5 MB loaded in 0.1s
# Area_5_scene_5_KDTree.pkl 21.1 MB loaded in 0.0s
# Area_6_scene_6_KDTree.pkl 38.5 MB loaded in 0.1s
# Area_4_scene_4_KDTree.pkl 19.0 MB loaded in 0.0s
# Area_1_scene_1_KDTree.pkl 21.1 MB loaded in 0.0s
# Area_3_scene_3_KDTree.pkl 119.8 MB loaded in 0.2s
#
# Preparing reprojected indices for testing
# Area_5_scene_5 done in 0.0s
# Initiating input pipelines
# WARNING:tensorflow:From main_S3DIS.py:170: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# WARNING:tensorflow:From main_S3DIS.py:205: The name tf.data.Iterator is deprecated. Please use tf.compat.v1.data.Iterator instead.
#
# WARNING:tensorflow:From main_S3DIS.py:205: DatasetV1.output_types (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_types(dataset)`.
# WARNING:tensorflow:From main_S3DIS.py:205: DatasetV1.output_shapes (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(dataset)`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:347: Iterator.output_types (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_types(iterator)`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:348: Iterator.output_shapes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_shapes(iterator)`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/data/ops/iterator_ops.py:350: Iterator.output_classes (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.data.get_output_classes(iterator)`.
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:29: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:42: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:107: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:108: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:49: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:54: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:22: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/util/dispatch.py:180: batch_gather (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.batch_gather` is deprecated, please use `tf.gather` with `batch_dims=-1` instead.
# WARNING:tensorflow:From /content/RandLA-Net/helper_tf_util.py:572: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:67: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:265: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:82: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:83: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:83: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:90: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:95: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:96: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:98: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:99: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:100: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /content/RandLA-Net/RandLANet.py:101: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Traceback (most recent call last):
#   File "main_S3DIS.py", line 241, in <module>
#     snap_steps = [int(f[:-5].split('-')[-1]) for f in os.listdir(snap_path) if f[-5:] == '.meta']
# FileNotFoundError: [Errno 2] No such file or directory: 'results/Log_2021-09-11_12-08-04/snapshots'

# %%
# !rm -rf /content/RandLA-Net/data/S3DIS/Stanford3dDataset_v1.2_Aligned_Version/Area_6*

# %%
# !python utils/6_fold_cv.py
# Out:
# Traceback (most recent call last):
#   File "utils/6_fold_cv.py", line 8, in <module>
#     from helper_tool import Plot
#   File "/content/RandLA-Net/helper_tool.py", line 1, in <module>
#     from open3d import linux as open3d
# ModuleNotFoundError: No module named 'open3d'

# %%
# !rm -r /content/RandLA-Net/models
# Out:
# rm: cannot remove '/content/RandLA-Net/models': No such file or directory

# %%
# !rm -r /content/RandLA-Net/Results
# Out:
# rm: cannot remove '/content/RandLA-Net/Results': No such file or directory

# %%
# !mv  /content/RandLA-Net/Results_2/S3DIS/*.ply /content/RandLA-Net/test
# Out:
# mv: cannot stat '/content/RandLA-Net/Results_2/S3DIS/*.ply': No such file or directory
